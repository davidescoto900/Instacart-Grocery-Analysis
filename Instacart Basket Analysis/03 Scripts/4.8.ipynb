# %%
# Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# Import your main ords_prods_merge dataframe. Call it ords_prods_merge

# %%
path= r'C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis'

# %%
ords_prods_merge= pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_new.pkl'))

# %%
# Create a subset called df of the first one million entries

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 23)

# %%
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             0   2539329        1    prior             1                   2
# 2             0   2539329        1    prior             1                   2
# 3             0   2539329        1    prior             1                   2
# 4             0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    ...                             product_name aisle_id  department_id  \
# 0  ...                                     Soda       77              7
# 1  ...  Organic Unsweetened Vanilla Almond Milk       91             16
# 2  ...                      Original Beef Jerky       23             19
# 3  ...               Aged White Cheddar Popcorn       23             19
# 4  ...         XL Pick-A-Size Paper Towel Rolls       54             17
#
#   prices  merge_status    price_range_loc     busiest day    busiest days  \
# 0    9.0          both  Mid-range product  Regularly busy  Regularly busy
# 1   12.5          both  Mid-range product  Regularly busy  Regularly busy
# 2    4.4          both  Low-range product  Regularly busy  Regularly busy
# 3    4.7          both  Low-range product  Regularly busy  Regularly busy
# 4    1.0          both  Low-range product  Regularly busy  Regularly busy
#
#     busiest hours busiest_period_of_day
# 0  Average orders        Average orders
# 1  Average orders        Average orders
# 2  Average orders        Average orders
# 3  Average orders        Average orders
# 4  Average orders        Average orders
#
# [5 rows x 23 columns]

# %%
df.groupby('product_name')

# %%
# Split the data into groups based on “department_id.”
# Apply the agg() function to each group to obtain the mean values for the “order_number” column

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15552\1681540670.py:1: FutureWarning: The provided callable <function max at 0x000002A0499205E0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             0   2539329        1    prior             1                   2
# 2             0   2539329        1    prior             1                   2
# 3             0   2539329        1    prior             1                   2
# 4             0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    ...  aisle_id department_id  prices merge_status    price_range_loc  \
# 0  ...        77             7     9.0         both  Mid-range product
# 1  ...        91            16    12.5         both  Mid-range product
# 2  ...        23            19     4.4         both  Low-range product
# 3  ...        23            19     4.7         both  Low-range product
# 4  ...        54            17     1.0         both  Low-range product
#
#       busiest day    busiest days   busiest hours busiest_period_of_day  \
# 0  Regularly busy  Regularly busy  Average orders        Average orders
# 1  Regularly busy  Regularly busy  Average orders        Average orders
# 2  Regularly busy  Regularly busy  Average orders        Average orders
# 3  Regularly busy  Regularly busy  Average orders        Average orders
# 4  Regularly busy  Regularly busy  Average orders        Average orders
#
#   max_order
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#
# [5 rows x 24 columns]

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# ..           ...       ...      ...      ...           ...
# 95            14    738281        2    prior             4
# 96            15   1673511        2    prior             5
# 97            15   1673511        2    prior             5
# 98            15   1673511        2    prior             5
# 99            15   1673511        2    prior             5
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    2                  8                     NaN       14084
# 2                    2                  8                     NaN       12427
# 3                    2                  8                     NaN       26088
# 4                    2                  8                     NaN       26405
# ..                 ...                ...                     ...         ...
# 95                   2                 10                     8.0       21150
# 96                   3                 11                     8.0       47144
# 97                   3                 11                     8.0        5322
# 98                   3                 11                     8.0       17224
# 99                   3                 11                     8.0       38656
#
#     add_to_cart_order  ...  aisle_id department_id  prices merge_status  \
# 0                   1  ...        77             7     9.0         both
# 1                   2  ...        91            16    12.5         both
# 2                   3  ...        23            19     4.4         both
# 3                   4  ...        23            19     4.7         both
# 4                   5  ...        54            17     1.0         both
# ..                ...  ...       ...           ...     ...          ...
# 95                 13  ...        38             1     5.9         both
# 96                  1  ...        91            16    14.0         both
# 97                  2  ...         3            19     2.9         both
# 98                  3  ...         3            19     1.6         both
# 99                  4  ...         3            19     3.4         both
#
#       price_range_loc     busiest day    busiest days   busiest hours  \
# 0   Mid-range product  Regularly busy  Regularly busy  Average orders
# 1   Mid-range product  Regularly busy  Regularly busy  Average orders
# 2   Low-range product  Regularly busy  Regularly busy  Average orders
# 3   Low-range product  Regularly busy  Regularly busy  Average orders
# 4   Low-range product  Regularly busy  Regularly busy  Average orders
# ..                ...             ...             ...             ...
# 95  Mid-range product  Regularly busy  Regularly busy     Most orders
# 96  Mid-range product  Regularly busy      Least busy     Most orders
# 97  Low-range product  Regularly busy      Least busy     Most orders
# 98  Low-range product  Regularly busy      Least busy     Most orders
# 99  Low-range product  Regularly busy      Least busy     Most orders
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2         Average orders        10
# 3         Average orders        10
# 4         Average orders        10
# ..                   ...       ...
# 95           Most orders        14
# 96           Most orders        14
# 97           Most orders        14
# 98           Most orders        14
# 99           Most orders        14
#
# [100 rows x 24 columns]

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
# 15             2    473747        1    prior             3
# 16             3   2254736        1    prior             4
# 17             3   2254736        1    prior             4
# 18             3   2254736        1    prior             4
# 19             3   2254736        1    prior             4
# 20             3   2254736        1    prior             4
# 21             4    431534        1    prior             5
# 22             4    431534        1    prior             5
# 23             4    431534        1    prior             5
# 24             4    431534        1    prior             5
# 25             4    431534        1    prior             5
# 26             4    431534        1    prior             5
# 27             4    431534        1    prior             5
# 28             4    431534        1    prior             5
# 29             5   3367565        1    prior             6
# 30             5   3367565        1    prior             6
# 31             5   3367565        1    prior             6
# 32             5   3367565        1    prior             6
# 33             6    550135        1    prior             7
# 34             6    550135        1    prior             7
# 35             6    550135        1    prior             7
# 36             6    550135        1    prior             7
# 37             6    550135        1    prior             7
# 38             7   3108588        1    prior             8
# 39             7   3108588        1    prior             8
# 40             7   3108588        1    prior             8
# 41             7   3108588        1    prior             8
# 42             7   3108588        1    prior             8
# 43             7   3108588        1    prior             8
# 44             8   2295261        1    prior             9
# 45             8   2295261        1    prior             9
# 46             8   2295261        1    prior             9
# 47             8   2295261        1    prior             9
# 48             8   2295261        1    prior             9
# 49             8   2295261        1    prior             9
# 50             9   2550362        1    prior            10
# 51             9   2550362        1    prior            10
# 52             9   2550362        1    prior            10
# 53             9   2550362        1    prior            10
# 54             9   2550362        1    prior            10
# 55             9   2550362        1    prior            10
# 56             9   2550362        1    prior            10
# 57             9   2550362        1    prior            10
# 58             9   2550362        1    prior            10
# 59            11   2168274        2    prior             1
# 60            11   2168274        2    prior             1
# 61            11   2168274        2    prior             1
# 62            11   2168274        2    prior             1
# 63            11   2168274        2    prior             1
# 64            11   2168274        2    prior             1
# 65            11   2168274        2    prior             1
# 66            11   2168274        2    prior             1
# 67            11   2168274        2    prior             1
# 68            11   2168274        2    prior             1
# 69            11   2168274        2    prior             1
# 70            11   2168274        2    prior             1
# 71            11   2168274        2    prior             1
# 72            12   1501582        2    prior             2
# 73            12   1501582        2    prior             2
# 74            12   1501582        2    prior             2
# 75            12   1501582        2    prior             2
# 76            12   1501582        2    prior             2
# 77            12   1501582        2    prior             2
# 78            13   1901567        2    prior             3
# 79            13   1901567        2    prior             3
# 80            13   1901567        2    prior             3
# 81            13   1901567        2    prior             3
# 82            13   1901567        2    prior             3
# 83            14    738281        2    prior             4
# 84            14    738281        2    prior             4
# 85            14    738281        2    prior             4
# 86            14    738281        2    prior             4
# 87            14    738281        2    prior             4
# 88            14    738281        2    prior             4
# 89            14    738281        2    prior             4
# 90            14    738281        2    prior             4
# 91            14    738281        2    prior             4
# 92            14    738281        2    prior             4
# 93            14    738281        2    prior             4
# 94            14    738281        2    prior             4
# 95            14    738281        2    prior             4
# 96            15   1673511        2    prior             5
# 97            15   1673511        2    prior             5
# 98            15   1673511        2    prior             5
# 99            15   1673511        2    prior             5
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    2                  8                     NaN       14084
# 2                    2                  8                     NaN       12427
# 3                    2                  8                     NaN       26088
# 4                    2                  8                     NaN       26405
# 5                    3                  7                    15.0         196
# 6                    3                  7                    15.0       10258
# 7                    3                  7                    15.0       12427
# 8                    3                  7                    15.0       13176
# 9                    3                  7                    15.0       26088
# 10                   3                  7                    15.0       13032
# 11                   3                 12                    21.0         196
# 12                   3                 12                    21.0       12427
# 13                   3                 12                    21.0       10258
# 14                   3                 12                    21.0       25133
# 15                   3                 12                    21.0       30450
# 16                   4                  7                    29.0         196
# 17                   4                  7                    29.0       12427
# 18                   4                  7                    29.0       10258
# 19                   4                  7                    29.0       25133
# 20                   4                  7                    29.0       26405
# 21                   4                 15                    28.0         196
# 22                   4                 15                    28.0       12427
# 23                   4                 15                    28.0       10258
# 24                   4                 15                    28.0       25133
# 25                   4                 15                    28.0       10326
# 26                   4                 15                    28.0       17122
# 27                   4                 15                    28.0       41787
# 28                   4                 15                    28.0       13176
# 29                   2                  7                    19.0         196
# 30                   2                  7                    19.0       12427
# 31                   2                  7                    19.0       10258
# 32                   2                  7                    19.0       25133
# 33                   1                  9                    20.0         196
# 34                   1                  9                    20.0       10258
# 35                   1                  9                    20.0       12427
# 36                   1                  9                    20.0       25133
# 37                   1                  9                    20.0       13032
# 38                   1                 14                    14.0       12427
# 39                   1                 14                    14.0         196
# 40                   1                 14                    14.0       10258
# 41                   1                 14                    14.0       25133
# 42                   1                 14                    14.0       46149
# 43                   1                 14                    14.0       49235
# 44                   1                 16                     0.0       49235
# 45                   1                 16                     0.0       46149
# 46                   1                 16                     0.0       25133
# 47                   1                 16                     0.0         196
# 48                   1                 16                     0.0       10258
# 49                   1                 16                     0.0       12427
# 50                   4                  8                    30.0         196
# 51                   4                  8                    30.0       46149
# 52                   4                  8                    30.0       39657
# 53                   4                  8                    30.0       38928
# 54                   4                  8                    30.0       25133
# 55                   4                  8                    30.0       10258
# 56                   4                  8                    30.0       35951
# 57                   4                  8                    30.0       13032
# 58                   4                  8                    30.0       12427
# 59                   2                 11                     NaN       32792
# 60                   2                 11                     NaN       47766
# 61                   2                 11                     NaN       20574
# 62                   2                 11                     NaN       12000
# 63                   2                 11                     NaN       48110
# 64                   2                 11                     NaN       22474
# 65                   2                 11                     NaN       16589
# 66                   2                 11                     NaN       35917
# 67                   2                 11                     NaN       27344
# 68                   2                 11                     NaN       30489
# 69                   2                 11                     NaN       27966
# 70                   2                 11                     NaN       13176
# 71                   2                 11                     NaN       45066
# 72                   5                 10                    10.0       16797
# 73                   5                 10                    10.0       47526
# 74                   5                 10                    10.0        8479
# 75                   5                 10                    10.0       47766
# 76                   5                 10                    10.0       19051
# 77                   5                 10                    10.0        8138
# 78                   1                 10                     3.0       47766
# 79                   1                 10                     3.0       32792
# 80                   1                 10                     3.0       20574
# 81                   1                 10                     3.0        7781
# 82                   1                 10                     3.0       28874
# 83                   2                 10                     8.0       49451
# 84                   2                 10                     8.0       32792
# 85                   2                 10                     8.0       32139
# 86                   2                 10                     8.0       34688
# 87                   2                 10                     8.0       36735
# 88                   2                 10                     8.0       37646
# 89                   2                 10                     8.0       22829
# 90                   2                 10                     8.0       24852
# 91                   2                 10                     8.0       47209
# 92                   2                 10                     8.0       33276
# 93                   2                 10                     8.0       45613
# 94                   2                 10                     8.0        9681
# 95                   2                 10                     8.0       21150
# 96                   3                 11                     8.0       47144
# 97                   3                 11                     8.0        5322
# 98                   3                 11                     8.0       17224
# 99                   3                 11                     8.0       38656
#
#     add_to_cart_order  ...  aisle_id department_id  prices merge_status  \
# 0                   1  ...        77             7     9.0         both
# 1                   2  ...        91            16    12.5         both
# 2                   3  ...        23            19     4.4         both
# 3                   4  ...        23            19     4.7         both
# 4                   5  ...        54            17     1.0         both
# 5                   1  ...        77             7     9.0         both
# 6                   2  ...       117            19     3.0         both
# 7                   3  ...        23            19     4.4         both
# 8                   4  ...        24             4    10.3         both
# 9                   5  ...        23            19     4.7         both
# 10                  6  ...       121            14     4.0         both
# 11                  1  ...        77             7     9.0         both
# 12                  2  ...        23            19     4.4         both
# 13                  3  ...       117            19     3.0         both
# 14                  4  ...        21            16     8.6         both
# 15                  5  ...        88            13     3.2         both
# 16                  1  ...        77             7     9.0         both
# 17                  2  ...        23            19     4.4         both
# 18                  3  ...       117            19     3.0         both
# 19                  4  ...        21            16     8.6         both
# 20                  5  ...        54            17     1.0         both
# 21                  1  ...        77             7     9.0         both
# 22                  2  ...        23            19     4.4         both
# 23                  3  ...       117            19     3.0         both
# 24                  4  ...        21            16     8.6         both
# 25                  5  ...        24             4     2.7         both
# 26                  6  ...        24             4    14.0         both
# 27                  7  ...        24             4     5.0         both
# 28                  8  ...        24             4    10.3         both
# 29                  1  ...        77             7     9.0         both
# 30                  2  ...        23            19     4.4         both
# 31                  3  ...       117            19     3.0         both
# 32                  4  ...        21            16     8.6         both
# 33                  1  ...        77             7     9.0         both
# 34                  2  ...       117            19     3.0         both
# 35                  3  ...        23            19     4.4         both
# 36                  4  ...        21            16     8.6         both
# 37                  5  ...       121            14     4.0         both
# 38                  1  ...        23            19     4.4         both
# 39                  2  ...        77             7     9.0         both
# 40                  3  ...       117            19     3.0         both
# 41                  4  ...        21            16     8.6         both
# 42                  5  ...        77             7    13.4         both
# 43                  6  ...        53            16     1.8         both
# 44                  1  ...        53            16     1.8         both
# 45                  2  ...        77             7    13.4         both
# 46                  3  ...        21            16     8.6         both
# 47                  4  ...        77             7     9.0         both
# 48                  5  ...       117            19     3.0         both
# 49                  6  ...        23            19     4.4         both
# 50                  1  ...        77             7     9.0         both
# 51                  2  ...        77             7    13.4         both
# 52                  3  ...        45            19     6.8         both
# 53                  4  ...       120            16    12.6         both
# 54                  5  ...        21            16     8.6         both
# 55                  6  ...       117            19     3.0         both
# 56                  7  ...        91            16     1.3         both
# 57                  8  ...       121            14     4.0         both
# 58                  9  ...        23            19     4.4         both
# 59                  1  ...        23            19     5.2         both
# 60                  2  ...        24             4     6.3         both
# 61                  3  ...        96            20     2.3         both
# 62                  4  ...        72            13    10.9         both
# 63                  5  ...        78            19     2.7         both
# 64                  6  ...        78            19     4.1         both
# 65                  7  ...       107            19     5.0         both
# 66                  8  ...        98             7     9.4         both
# 67                  9  ...        96            20    14.8         both
# 68                 10  ...        67            20     7.5         both
# 69                 11  ...       123             4     4.4         both
# 70                 12  ...        24             4    10.3         both
# 71                 13  ...        24             4     2.5         both
# 72                  1  ...        24             4     1.3         both
# 73                  2  ...        21            16     2.0         both
# 74                  3  ...        78            19     3.5         both
# 75                  4  ...        24             4     6.3         both
# 76                  5  ...       107            19     3.9         both
# 77                  6  ...        67            20     2.0         both
# 78                  1  ...        24             4     6.3         both
# 79                  2  ...        23            19     5.2         both
# 80                  3  ...        96            20     2.3         both
# 81                  4  ...        21            16     6.6         both
# 82                  5  ...         1            20     6.2         both
# 83                  1  ...        67            20     7.1         both
# 84                  2  ...        23            19     5.2         both
# 85                  3  ...        67            20     7.5         both
# 86                  4  ...        31             7     5.8         both
# 87                  5  ...        96            20     8.9         both
# 88                  6  ...        24             4     9.1         both
# 89                  7  ...        78            19     5.5         both
# 90                  8  ...        24             4    12.3         both
# 91                  9  ...        24             4     4.0         both
# 92                 10  ...        67            20    10.8         both
# 93                 11  ...        38             1    12.6         both
# 94                 12  ...        38             1     2.0         both
# 95                 13  ...        38             1     5.9         both
# 96                  1  ...        91            16    14.0         both
# 97                  2  ...         3            19     2.9         both
# 98                  3  ...         3            19     1.6         both
# 99                  4  ...         3            19     3.4         both
#
#       price_range_loc     busiest day    busiest days   busiest hours  \
# 0   Mid-range product  Regularly busy  Regularly busy  Average orders
# 1   Mid-range product  Regularly busy  Regularly busy  Average orders
# 2   Low-range product  Regularly busy  Regularly busy  Average orders
# 3   Low-range product  Regularly busy  Regularly busy  Average orders
# 4   Low-range product  Regularly busy  Regularly busy  Average orders
# 5   Mid-range product  Regularly busy      Least busy  Average orders
# 6   Low-range product  Regularly busy      Least busy  Average orders
# 7   Low-range product  Regularly busy      Least busy  Average orders
# 8   Mid-range product  Regularly busy      Least busy  Average orders
# 9   Low-range product  Regularly busy      Least busy  Average orders
# 10  Low-range product  Regularly busy      Least busy  Average orders
# 11  Mid-range product  Regularly busy      Least busy  Average orders
# 12  Low-range product  Regularly busy      Least busy  Average orders
# 13  Low-range product  Regularly busy      Least busy  Average orders
# 14  Mid-range product  Regularly busy      Least busy  Average orders
# 15  Low-range product  Regularly busy      Least busy  Average orders
# 16  Mid-range product      Least busy      Least busy  Average orders
# 17  Low-range product      Least busy      Least busy  Average orders
# 18  Low-range product      Least busy      Least busy  Average orders
# 19  Mid-range product      Least busy      Least busy  Average orders
# 20  Low-range product      Least busy      Least busy  Average orders
# 21  Mid-range product      Least busy      Least busy     Most orders
# 22  Low-range product      Least busy      Least busy     Most orders
# 23  Low-range product      Least busy      Least busy     Most orders
# 24  Mid-range product      Least busy      Least busy     Most orders
# 25  Low-range product      Least busy      Least busy     Most orders
# 26  Mid-range product      Least busy      Least busy     Most orders
# 27                NaN      Least busy      Least busy     Most orders
# 28  Mid-range product      Least busy      Least busy     Most orders
# 29  Mid-range product  Regularly busy  Regularly busy  Average orders
# 30  Low-range product  Regularly busy  Regularly busy  Average orders
# 31  Low-range product  Regularly busy  Regularly busy  Average orders
# 32  Mid-range product  Regularly busy  Regularly busy  Average orders
# 33  Mid-range product  Regularly busy    Busiest days  Average orders
# 34  Low-range product  Regularly busy    Busiest days  Average orders
# 35  Low-range product  Regularly busy    Busiest days  Average orders
# 36  Mid-range product  Regularly busy    Busiest days  Average orders
# 37  Low-range product  Regularly busy    Busiest days  Average orders
# 38  Low-range product  Regularly busy    Busiest days     Most orders
# 39  Mid-range product  Regularly busy    Busiest days     Most orders
# 40  Low-range product  Regularly busy    Busiest days     Most orders
# 41  Mid-range product  Regularly busy    Busiest days     Most orders
# 42  Mid-range product  Regularly busy    Busiest days     Most orders
# 43  Low-range product  Regularly busy    Busiest days     Most orders
# 44  Low-range product  Regularly busy    Busiest days  Average orders
# 45  Mid-range product  Regularly busy    Busiest days  Average orders
# 46  Mid-range product  Regularly busy    Busiest days  Average orders
# 47  Mid-range product  Regularly busy    Busiest days  Average orders
# 48  Low-range product  Regularly busy    Busiest days  Average orders
# 49  Low-range product  Regularly busy    Busiest days  Average orders
# 50  Mid-range product      Least busy      Least busy  Average orders
# 51  Mid-range product      Least busy      Least busy  Average orders
# 52  Mid-range product      Least busy      Least busy  Average orders
# 53  Mid-range product      Least busy      Least busy  Average orders
# 54  Mid-range product      Least busy      Least busy  Average orders
# 55  Low-range product      Least busy      Least busy  Average orders
# 56  Low-range product      Least busy      Least busy  Average orders
# 57  Low-range product      Least busy      Least busy  Average orders
# 58  Low-range product      Least busy      Least busy  Average orders
# 59  Mid-range product  Regularly busy  Regularly busy     Most orders
# 60  Mid-range product  Regularly busy  Regularly busy     Most orders
# 61  Low-range product  Regularly busy  Regularly busy     Most orders
# 62  Mid-range product  Regularly busy  Regularly busy     Most orders
# 63  Low-range product  Regularly busy  Regularly busy     Most orders
# 64  Low-range product  Regularly busy  Regularly busy     Most orders
# 65                NaN  Regularly busy  Regularly busy     Most orders
# 66  Mid-range product  Regularly busy  Regularly busy     Most orders
# 67  Mid-range product  Regularly busy  Regularly busy     Most orders
# 68  Mid-range product  Regularly busy  Regularly busy     Most orders
# 69  Low-range product  Regularly busy  Regularly busy     Most orders
# 70  Mid-range product  Regularly busy  Regularly busy     Most orders
# 71  Low-range product  Regularly busy  Regularly busy     Most orders
# 72  Low-range product  Regularly busy  Regularly busy     Most orders
# 73  Low-range product  Regularly busy  Regularly busy     Most orders
# 74  Low-range product  Regularly busy  Regularly busy     Most orders
# 75  Mid-range product  Regularly busy  Regularly busy     Most orders
# 76  Low-range product  Regularly busy  Regularly busy     Most orders
# 77  Low-range product  Regularly busy  Regularly busy     Most orders
# 78  Mid-range product  Regularly busy    Busiest days     Most orders
# 79  Mid-range product  Regularly busy    Busiest days     Most orders
# 80  Low-range product  Regularly busy    Busiest days     Most orders
# 81  Mid-range product  Regularly busy    Busiest days     Most orders
# 82  Mid-range product  Regularly busy    Busiest days     Most orders
# 83  Mid-range product  Regularly busy  Regularly busy     Most orders
# 84  Mid-range product  Regularly busy  Regularly busy     Most orders
# 85  Mid-range product  Regularly busy  Regularly busy     Most orders
# 86  Mid-range product  Regularly busy  Regularly busy     Most orders
# 87  Mid-range product  Regularly busy  Regularly busy     Most orders
# 88  Mid-range product  Regularly busy  Regularly busy     Most orders
# 89  Mid-range product  Regularly busy  Regularly busy     Most orders
# 90  Mid-range product  Regularly busy  Regularly busy     Most orders
# 91  Low-range product  Regularly busy  Regularly busy     Most orders
# 92  Mid-range product  Regularly busy  Regularly busy     Most orders
# 93  Mid-range product  Regularly busy  Regularly busy     Most orders
# 94  Low-range product  Regularly busy  Regularly busy     Most orders
# 95  Mid-range product  Regularly busy  Regularly busy     Most orders
# 96  Mid-range product  Regularly busy      Least busy     Most orders
# 97  Low-range product  Regularly busy      Least busy     Most orders
# 98  Low-range product  Regularly busy      Least busy     Most orders
# 99  Low-range product  Regularly busy      Least busy     Most orders
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2         Average orders        10
# 3         Average orders        10
# 4         Average orders        10
# 5         Average orders        10
# 6         Average orders        10
# 7         Average orders        10
# 8         Average orders        10
# 9         Average orders        10
# 10        Average orders        10
# 11        Average orders        10
# 12        Average orders        10
# 13        Average orders        10
# 14        Average orders        10
# 15        Average orders        10
# 16        Average orders        10
# 17        Average orders        10
# 18        Average orders        10
# 19        Average orders        10
# 20        Average orders        10
# 21           Most orders        10
# 22           Most orders        10
# 23           Most orders        10
# 24           Most orders        10
# 25           Most orders        10
# 26           Most orders        10
# 27           Most orders        10
# 28           Most orders        10
# 29        Average orders        10
# 30        Average orders        10
# 31        Average orders        10
# 32        Average orders        10
# 33        Average orders        10
# 34        Average orders        10
# 35        Average orders        10
# 36        Average orders        10
# 37        Average orders        10
# 38           Most orders        10
# 39           Most orders        10
# 40           Most orders        10
# 41           Most orders        10
# 42           Most orders        10
# 43           Most orders        10
# 44        Average orders        10
# 45        Average orders        10
# 46        Average orders        10
# 47        Average orders        10
# 48        Average orders        10
# 49        Average orders        10
# 50        Average orders        10
# 51        Average orders        10
# 52        Average orders        10
# 53        Average orders        10
# 54        Average orders        10
# 55        Average orders        10
# 56        Average orders        10
# 57        Average orders        10
# 58        Average orders        10
# 59           Most orders        14
# 60           Most orders        14
# 61           Most orders        14
# 62           Most orders        14
# 63           Most orders        14
# 64           Most orders        14
# 65           Most orders        14
# 66           Most orders        14
# 67           Most orders        14
# 68           Most orders        14
# 69           Most orders        14
# 70           Most orders        14
# 71           Most orders        14
# 72           Most orders        14
# 73           Most orders        14
# 74           Most orders        14
# 75           Most orders        14
# 76           Most orders        14
# 77           Most orders        14
# 78           Most orders        14
# 79           Most orders        14
# 80           Most orders        14
# 81           Most orders        14
# 82           Most orders        14
# 83           Most orders        14
# 84           Most orders        14
# 85           Most orders        14
# 86           Most orders        14
# 87           Most orders        14
# 88           Most orders        14
# 89           Most orders        14
# 90           Most orders        14
# 91           Most orders        14
# 92           Most orders        14
# 93           Most orders        14
# 94           Most orders        14
# 95           Most orders        14
# 96           Most orders        14
# 97           Most orders        14
# 98           Most orders        14
# 99           Most orders        14
#
# [100 rows x 24 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_final.pkl'))
