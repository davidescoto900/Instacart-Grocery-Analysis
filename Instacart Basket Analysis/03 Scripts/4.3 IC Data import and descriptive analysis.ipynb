# %% [markdown]
# ## 0.1 Importing Libraries

# %%
# Import libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing data

# %%
df= pd.read_csv(r"C:\Users\You\Documents\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df= pd.read_csv(r"C:\Users\You\Documents\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
#
# File ~\anaconda4\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df= pd.read_csv(r"C:\Users\You\One Drive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df= pd.read_csv(r"C:\Users\You\One Drive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\You\One Drive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df= pd.read_csv(r"C:\Users\You\One Drive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
#
# ...

# %%
df= pd.read_csv(r"C:One Drive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df= pd.read_csv(r"C:One Drive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data", index_col = False)
#
# ...

# %%
import glob

# %%
# Importing orders file 
df =  pd.read_csv(r"C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data\orders.csv", index_col=False)

# %%
project_folder = r"C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis"

# %%
df = pd.read_csv(os.path.join(project_folder,"02 Data","Original Data","orders.csv"),index_col = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv(os.path.join(project_folder,"02 Data","Original Data","orders.csv"),index_col = False)
#
# NameError: name 'os' is not defined

# %%
import os

# %%
df = pd.read_csv(os.path.join(project_folder,"02 Data","Original Data","orders.csv"),index_col = False)

# %%
print(df.head())
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df=pd.read_csv(r"C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data\orders.csv",index_col= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv(r"C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data\orders.csv",index_col= False)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis\02 Data\Original Data\orders.csv",index_col= False)

# %%
path = r"C:\Users\user\OneDrive - Universitat de Barcelona\Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\user\\OneDrive - Universitat de Barcelona\\Instacart Basket Analysis'

# %%
import os

# %%
df=pd.read_csv(os.path.join(path, "02 Data","Original Data", "orders.csv"),index_col= False)

# %%
df.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df.tail()
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
df.shape
# Out:
# (3421083, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
df.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), nrows=1000)

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
vars list
# Out:
#   Cell In[20], line 1
#     vars list
#          ^
# SyntaxError: invalid syntax

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
